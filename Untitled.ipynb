# %%
import pandas as pd
import json
# import pyjsonviewer

# %%
# dir(pyjsonviewer)

# %%
# !pip install --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org PyJSONViewer==1.4.0

# %%
df = pd.read_parquet('ITR_sample.parquet')
df['report'] = df['report'].apply(lambda x: json.loads(x.decode('utf-8')))
df['itr_type']=df.apply(lambda x:list((x['report'])['ITR'].keys())[0], axis=1)
df
# Out:
#     application_id                                             report
# 0          1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...  \
# 1          1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 2          1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 3          1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 4          1572177  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# ..             ...                                                ...
# 56         1572104  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...
# 57         1572096  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...
# 58         1572096  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...
# 59         1572101  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 60         1572102  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
#
#           created_date  year itr_type
# 0  2023-04-12 13:07:07  2022     ITR3
# 1  2023-04-12 13:07:07  2021     ITR3
# ...

# %%
# df['report'] = df['report'].apply(lambda x: json.loads(x.decode('utf-8')))
# df['itr_type']=df.apply(lambda x:list((x['report'])['ITR'].keys())[0], axis=1)

# %%
df['report'][3]['ITR']['ITR3']['TradingAccount']['DutyTaxPay']
# Out:
# {'ExciseCustomsVAT': {'CustomDuty': 0,
#   'CounterVailDuty': 0,
#   'SplAddDuty': 0,
#   'UnionExciseDuty': 0,
#   'ServiceTax': 0,
#   'VATorSaleTax': 0,
#   'CentralGoodServiceTax': 0,
#   'StateGoodServiceTax': 0,
#   'IntegratedGoodServiceTax': 0,
#   'UnionTerrGoodServiceTax': 0,
#   'OthDutyTaxCess': 0,
#   'TotExciseCustomsVAT': 0}}

# %%
pd.DataFrame([df['report'][3]['ITR']['ITR3']['TradingAccount']['DutyTaxPay']['ExciseCustomsVAT']])
# Out:
#    CustomDuty  CounterVailDuty  SplAddDuty  UnionExciseDuty  ServiceTax
# 0           0                0           0                0           0  \
#
#    VATorSaleTax  CentralGoodServiceTax  StateGoodServiceTax
# 0             0                      0                    0  \
#
#    IntegratedGoodServiceTax  UnionTerrGoodServiceTax  OthDutyTaxCess
# 0                         0                        0               0  \
#
#    TotExciseCustomsVAT
# 0                    0

# %%
# pyjsonviewer(json_data = json.loads(df['report'][0]))

# %%
print(df['itr_type'].value_counts())
df
# Out:
# itr_type
# ITR3    28
# ITR4    20
# ITR6     7
# ITR5     6
# Name: count, dtype: int64
#     application_id                                             report
# 0          1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...  \
# 1          1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 2          1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 3          1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 4          1572177  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# ..             ...                                                ...
# 56         1572104  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...
# 57         1572096  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...
# 58         1572096  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...
# 59         1572101  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 60         1572102  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
#
#           created_date  year itr_type
# ...

# %%
itr_form_type = 'ITR5'
itr_form = 'Form_ITR5'

# %%
df['report'][39]['ITR']['ITR6'].keys()
# Out:
# dict_keys(['CreationInfo', 'Form_ITR6', 'PartA_GEN1', 'PartA_GEN2For6', 'PARTA_BSFor6FrmAY13', 'PARTA_BSIndAS', 'ManufacturingAccount', 'TradingAccount', 'PARTA_PL', 'PARTA_PLIndAS', 'PARTA_OI', 'CorpScheduleBP', 'ScheduleDPM', 'ScheduleDOA', 'ScheduleDEP', 'ScheduleCG', 'Schedule112A', 'ScheduleOS', 'ScheduleCYLA', 'ScheduleBFLA', 'ScheduleCFL', 'ITRScheduleUD', 'ScheduleICDS', 'Schedule80RA', 'ScheduleSI', 'ScheduleMAT', 'ScheduleMATC', 'ScheduleTPSA', 'ScheduleGST', 'PartB-TI', 'PartB_TTI', 'ScheduleIT', 'ScheduleTDS2', 'ScheduleTDS3', 'ScheduleTCS', 'Verification'])

# %%
itr_6_idx = list(df[df['itr_type']=='ITR6'].index)
itr_3_idx = list(df[df['itr_type']=='ITR3'].index)
itr_4_idx = list(df[df['itr_type']=='ITR4'].index)
itr_5_idx = list(df[df['itr_type']=='ITR5'].index)

print(f'''
---> itr3 idx {itr_3_idx}
---> itr4 idx {itr_4_idx}
---> itr5 idx {itr_5_idx}
---> itr6 idx {itr_6_idx}
''')
# Out:
# ---> itr3 idx [0, 1, 2, 3, 4, 5, 9, 10, 11, 12, 13, 14, 15, 18, 28, 29, 30, 31, 32, 33, 37, 43, 45, 46, 47, 50, 59, 60]
# ---> itr4 idx [16, 17, 22, 23, 24, 25, 26, 27, 34, 38, 40, 41, 42, 44, 53, 54, 55, 56, 57, 58]
# ---> itr5 idx [19, 20, 35, 36, 48, 49]
# ---> itr6 idx [6, 7, 8, 21, 39, 51, 52]

# %%
df['report'][51]['ITR']['ITR6']['PartA_GEN2For6']
# Out:
# {'AuditInfo': {'AuditReportFurnishDate': '2022-09-02',
#   'AuditorName': 'CA Kamendra Kumar Singh',
#   'AuditorMemNo': '052939',
#   'AudFrmName': 'M/S SINGH RAY MISHRA & CO.',
#   'AudFrmRegNo': '0318121E',
#   'AudFrmPAN': 'AAIFS9174K',
#   'AuditDate': '2022-09-02'},
#  'AuditReportDetails': [{'AuditReportAct': '6',
#    'AuditReportSection': '143',
#    'OtherITActFlag': 'Y',
#    'AuditReportDate': '2022-09-02'}],
#  'HoldingStatus': {'NatOfCompFlg': '4'},
#  'KeyPersons': [{'AddressDetailWithZipCode': {'AddrDetail': 'Kidwaipuri',
#     'CityOrTownOrDistrict': 'Patna',
#     'StateCode': '05',
#     'CountryCode': '91',
#     'PinCode': 800001},
#    'PersonName': 'ATUL PARASHAR',
#    'Designation': 'DIR',
#    'KeyPerPAN': 'AHZPP4351M',
#    'DirectorIdNo': '02312644'},
#   {'AddressDetailWithZipCode': {'AddrDetail': 'Kidwaipuri',
#     'CityOrTownOrDistrict': 'Patna',
#     'StateCode': '05',
#     'CountryCode': '91',
#     'PinCode': 800001},
# ...

# %%
df['report'][39]['ITR']['ITR6']['PartA_GEN2For6']['ShareHolderInfo']
# Out:
# [{'AddressDetailWithZipCode': {'AddrDetail': 'No: 29/15, 42nd Jegajeevaram, Street,gkm Colony,Jawahar Nagar Post',
#    'CityOrTownOrDistrict': 'CHENNAI',
#    'StateCode': '29',
#    'CountryCode': '91',
#    'PinCode': 600082},
#   'ShareHolderInfoName': 'SUBRAMANIAM SHANMUGASUNDARAM',
#   'PercentageOfShare': 50,
#   'ShareHolderPAN': 'BNMPS1265B'},
#  {'AddressDetailWithZipCode': {'AddrDetail': 'No. 48 R B Builders, Sundar Nagar, Poonamallee',
#    'CityOrTownOrDistrict': 'CHENNAI',
#    'StateCode': '29',
#    'CountryCode': '91',
#    'PinCode': 600056},
#   'ShareHolderInfoName': 'NARAYANASAMY SUGANTHI',
#   'PercentageOfShare': 25,
#   'ShareHolderPAN': 'KBEPS2182E'},
#  {'AddressDetailWithZipCode': {'AddrDetail': 'No 40/20, Fahad Palace, Kamarajar Street B.v. Nagar, Nanganallur',
#    'CityOrTownOrDistrict': 'KANCHEEPURAM',
#    'StateCode': '29',
#    'CountryCode': '91',
#    'PinCode': 600061},
#   'ShareHolderInfoName': 'KRISHNAVENI NAGARAJAN',
# ...

# %%
df['report'][0]['ITR']['ITR3']['PartA_GEN1'].keys()
# Out:
# dict_keys(['PersonalInfo', 'FilingStatus'])

# %%
print(df['report'][48]['ITR']['ITR5'].keys())
# Out:
# dict_keys(['CreationInfo', 'Form_ITR5', 'PartA_GEN1', 'PartA_GEN2', 'PARTA_BS', 'ManufacturingAccount', 'TradingAccount', 'PARTA_PL', 'PARTA_OI', 'ScheduleHP', 'CorpScheduleBP', 'ScheduleDPM', 'ScheduleDOA', 'ScheduleDEP', 'ScheduleDCG', 'ScheduleCG', 'Schedule112A', 'Schedule115AD', 'ScheduleOS', 'ScheduleCYLA', 'ScheduleBFLA', 'ScheduleCFL', 'Schedule80G', 'ScheduleVIA', 'ScheduleAMT', 'ScheduleAMTC', 'ScheduleSI', 'ScheduleEI', 'ScheduleTPSA', 'ScheduleTR1', 'ScheduleFA', 'ScheduleGST', 'PartB-TI', 'PartB_TTI', 'ScheduleTDS2', 'ScheduleTCS', 'Verification'])

# %%
df['report'][48]['ITR']['ITR5']['PartA_GEN1'].keys()
# Out:
# dict_keys(['OrgFirmInfo', 'FilingStatus'])

# %%
df['report'][48]['ITR']['ITR5']['PartA_GEN2']
# Out:
# {'LiableSec44AAflg': 'Y',
#  'IncDclrdUs': 'N',
#  'TotalSalesExcOneCr': 'N',
#  'LiableSec44ABflg': 'Y',
#  'AuditedByAccountantFlg': 'Y',
#  'AuditInfo': {'AuditReportFurnishDate': '2022-09-09',
#   'AuditorName': 'RAJ KUMAR SINGHAL',
#   'AuditorMemNo': '401909',
#   'AudFrmName': 'RHMS & CO',
#   'AudFrmRegNo': '0011508C',
#   'AudFrmPAN': 'APBPS5083A',
#   'AuditDate': '2022-08-17'},
#  'LiableSec92Eflg': 'N',
#  'PrevYrMemPartChange': 'N',
#  'PartnerOrMemberInfo': [{'PartnerForeignCompFlg': 'NO',
#    'PartnerOrMemberName': 'MANOJ BANSAL',
#    'AddressDetailWithZipCode': {'AddrDetail': 'SRI GANGANAGAR',
#     'CityOrTownOrDistrict': 'SRI GANGANAGAR',
#     'StateCode': '27',
#     'CountryCode': '91',
#     'PinCode': 335001},
#    'SharePercentage': 50,
#    'PAN': 'AKLPB4412G',
#    'AadhaarCardNo': '776841948203',
#    'Status': 'INDIVIDUAL',
#    'RateOfInterest': 12,
#    'RemunerationPaid': 77198},
#   {'PartnerForeignCompFlg': 'NO',
# ...

# %%
print(df['report'][21]['ITR']['ITR6'].keys())
# Out:
# dict_keys(['CreationInfo', 'Form_ITR6', 'PartA_GEN1', 'PartA_GEN2For6', 'PARTA_BSFor6FrmAY13', 'PARTA_BSIndAS', 'ManufacturingAccount', 'TradingAccount', 'PARTA_PL', 'ManufacturingAccountIndAS', 'TradingAccountIndAS', 'PARTA_PLIndAS', 'PARTA_OI', 'PARTA_OL', 'CorpScheduleBP', 'ScheduleDPM', 'ScheduleDOA', 'ScheduleDEP', 'ScheduleDCG', 'ScheduleCG', 'ScheduleOS', 'ScheduleCYLA', 'ScheduleBFLA', 'ScheduleCFL', 'ITRScheduleUD', 'Schedule80G', 'Schedule80_IA', 'Schedule80_IB', 'Schedule80_IC', 'ScheduleVIA', 'ScheduleEI', 'ScheduleMAT', 'ScheduleMATC', 'ScheduleFD', 'PartB-TI', 'PartB_TTI', 'Verification'])

# %%
df['report'][21]['ITR']['ITR6']['PartA_GEN2For6'].keys()
# Out:
# dict_keys(['LiableSec44AAflg', 'IncDclrdUs', 'TotalSalesExcOneCr', 'LiableSec44ABflg', 'LiableSec92Eflg', 'AccountAuditFlag', 'HoldingStatus', 'BusOrganisation', 'KeyPersons', 'ShareHolderInfo', 'NatureOfComp', 'NatOfBus'])

# %%
df['report'][19]['ITR'][itr_form_type]['PARTA_PL']['DebitsToPL']['DebitPlAcnt']['OtherExpensesDtls'][i].keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df['report'][19]['ITR'][itr_form_type]['PARTA_PL']['DebitsToPL']['DebitPlAcnt']['OtherExpensesDtls'][i].keys()
#
# NameError: name 'i' is not defined

# %%
if 'DebitsToPL' in df['report'][19]['ITR'][itr_form_type]['PARTA_PL'] and 'DebitPlAcnt' in df['report'][19]['ITR'][itr_form_type]['PARTA_PL']['DebitsToPL'] and 'OtherExpensesDtls' in df['report'][19]['ITR'][itr_form_type]['PARTA_PL']['DebitsToPL']['DebitPlAcnt']:
    expense_nature_list = []
    expense_amount_list = []
    expense_count = len(df['report'][19]['ITR'][itr_form_type]['PARTA_PL']['DebitsToPL']['DebitPlAcnt']['OtherExpensesDtls'])
    for i in range(expense_count):
        for i in range(expense_count):
            expense_nature = df['report'][19]['ITR'][itr_form_type]['PARTA_PL']['DebitsToPL']['DebitPlAcnt']['OtherExpensesDtls'][i].values()
            expense_amount = df['report'][19]['ITR'][itr_form_type]['PARTA_PL']['DebitsToPL']['DebitPlAcnt']['OtherExpensesDtls'][i].values()

            expense_nature_list.append((list(expense_nature)[0]))
            expense_amount_list.append(list(expense_nature)[1])

# %%
# a['ITR'].keys()

# %%
# a['ITR']['ITR3'].keys()break

# %%
df_itr5 = df[df['itr_type'] == 'ITR5'].reset_index(drop=True)
df_itr3 = df[df['itr_type'] == 'ITR3'].reset_index(drop=True)
df_itr4 = df[df['itr_type'] == 'ITR4'].reset_index(drop=True)
df_itr6 = df[df['itr_type'] == 'ITR6'].reset_index(drop=True)

# %%
df=df_itr3
for i in df.iloc[2,:]['report']['ITR']['ITR3'].keys():
        print(i)
        a =df.iloc[2,:]['report']
#         a = df['report']
#         # print(a)
# #     if type(a['ITR']['ITR3'][i]) == dict:
#         print(f'-------------------------------------*****{i}*****--------------------------------------')
#         i = a['ITR']['ITR3'].keys()
        print(a['ITR']['ITR3'][i])
        print('''\n-*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*\n''')
# Out:
# CreationInfo
# {'SWVersionNo': '2.22.10.2', 'SWCreatedBy': 'SW20000126', 'JSONCreatedBy': 'SW20000126', 'JSONCreationDate': '2022-11-03', 'IntermediaryCity': 'JAIPUR', 'Digest': 'WSQM8/rSCngpZXViXPQcXOSzNSrXrScIWf7TAqmnGf0='}
#
# -*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*
#
# Form_ITR3
# {'FormName': 'ITR-3', 'Description': 'For indls and HUFs having income from a proprietory business or profession', 'AssessmentYear': '2022', 'SchemaVer': 'Ver1.0', 'FormVer': 'Ver1.0'}
#
# -*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*
#
# PartA_GEN1
# ...

# %%
df = df_itr5
print(df.index)
for i in df.iloc[5,:]['report']['ITR']['ITR5'].keys():
        print(i)
        a =df.iloc[5,:]['report']
#         a = df['report']
#         # print(a)
# #     if type(a['ITR']['ITR3'][i]) == dict:
#         print(f'-------------------------------------*****{i}*****--------------------------------------')
#         i = a['ITR']['ITR3'].keys()
        print(a['ITR']['ITR5'][i])
        print('''\n-*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*\n''')
# Out:
# RangeIndex(start=0, stop=6, step=1)
# CreationInfo
# {'SWVersionNo': '21.5', 'SWCreatedBy': 'SW20000026', 'JSONCreatedBy': 'SW20000026', 'JSONCreationDate': '2022-02-15', 'IntermediaryCity': 'JAIPUR', 'Digest': 'b76djqo4q86lX68w3o87nhWcApi3bjOYugqzTjcaM9k='}
#
# -*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*
#
# Form_ITR5
# {'FormName': 'ITR-5', 'Description': 'For firms, AOPs and BOIs', 'AssessmentYear': '2021', 'SchemaVer': 'Ver1.1', 'FormVer': 'Ver1.0'}
#
# -*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*
#
# PartA_GEN1
# ...

# %%
df = df_itr6
print(df.index)
for i in df.iloc[5,:]['report']['ITR']['ITR6'].keys():
        print(i)
        a =df.iloc[5,:]['report']
#         a = df['report']
#         # print(a)
# #     if type(a['ITR']['ITR3'][i]) == dict:
#         print(f'-------------------------------------*****{i}*****--------------------------------------')
#         i = a['ITR']['ITR3'].keys()
        print(a['ITR']['ITR6'][i])
        print('''\n-*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*\n''')
# Out:
# RangeIndex(start=0, stop=7, step=1)
# CreationInfo
# {'SWVersionNo': 'R7', 'SWCreatedBy': 'SW00012223', 'JSONCreatedBy': 'SW00012223', 'JSONCreationDate': '2022-12-31', 'Digest': 'mexj4VvWNyMsmbjlJdT0G5XC3nuSpYAZqlNmyb7jSVQ=', 'IntermediaryCity': 'Delhi'}
#
# -*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*
#
# Form_ITR6
# {'FormName': 'ITR-6', 'Description': 'For Companies other than companies claiming exemption under section 11', 'AssessmentYear': '2022', 'SchemaVer': 'Ver1.0', 'FormVer': 'Ver1.0'}
#
# -*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*
#
# PartA_GEN1
# ...

# %%
a['ITR']['ITR3']['PartA_GEN2'].keys()
# Out:
# dict_keys(['AuditInfo', 'NatOfBus'])

# %%
df.head()
# Out:
#    application_id                                             report
# 0         1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...  \
# 1         1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 2         1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 3         1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 4         1572177  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
#
#          created_date  year itr_type
# 0 2023-04-12 13:07:07  2022     ITR3
# 1 2023-04-12 13:07:07  2021     ITR3
# 2 2023-04-14 12:23:11  2022     ITR3
# 3 2023-04-14 12:23:11  2021     ITR3
# 4 2023-04-12 13:07:07  2022     ITR3

# %%
df.itr_type.value_counts()
# Out:
# itr_type
# ITR3    28
# Name: count, dtype: int64

# %%
df_itr3 = df[df['itr_type'] == 'ITR3']
df_itr4 = df[df['itr_type'] == 'ITR4']
df_itr5 = df[df['itr_type'] == 'ITR5']
df_itr6 = df[df['itr_type'] == 'ITR6']

# %%
df_itr3.head()
# Out:
#    application_id                                             report
# 0         1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...  \
# 1         1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 2         1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 3         1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 4         1572177  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
#
#          created_date  year itr_type
# 0 2023-04-12 13:07:07  2022     ITR3
# 1 2023-04-12 13:07:07  2021     ITR3
# 2 2023-04-14 12:23:11  2022     ITR3
# 3 2023-04-14 12:23:11  2021     ITR3
# 4 2023-04-12 13:07:07  2022     ITR3

# %%
df_itr3.hea
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_itr3.hea
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'hea'

# %%
df_itr4.head()

# %%
df_itr5.head()

# %%
df_itr6.head()

# %%
itr_3_norm = pd.concat([df_itr3.reset_index(drop=True),pd.json_normalize(df_itr3['report'],sep='_')],axis=1)
itr_3_norm.columns = [s.replace('ITR_ITR3_', '') for s in itr_3_norm.columns]
itr_3_norm.isna().sum()
# Out:
# application_id                                                                0
# report                                                                        0
# created_date                                                                  0
# year                                                                          0
# itr_type                                                                      0
#                                                                              ..
# Schedule10AA_DeductSEZ_DedUs10Detail_Undertaking_DedFromUndertakingWithAy    27
# Schedule10AA_DeductSEZ_DedUs10Detail_TotalDedUs10Sub                         27
# PartA_GEN1_PersonalInfo_Address_EmailAddressSec                              21
# ScheduleOS_IncOthThanOwnRaceHorse_OthersInc_OthersIncDtls                    26
# PARTA_QD_TradingConcern_QuantitDet                                           27
# Length: 1637, dtype: int64

# %%
itr_4_norm = pd.concat([df_itr4.reset_index(drop=True),pd.json_normalize(df_itr4['report'],sep='_')],axis=1)
itr_4_norm.columns = [s.replace('ITR_ITR5_', '') for s in itr_4_norm.columns]
itr_4_norm.isna().sum()
# Out:
# application_id    0.0
# report            0.0
# created_date      0.0
# year              0.0
# itr_type          0.0
# dtype: float64

# %%
itr_5_norm = pd.concat([df_itr5.reset_index(drop=True),pd.json_normalize(df_itr5['report'],sep='_')],axis=1)
itr_5_norm.columns = [s.replace('ITR_ITR5_', '') for s in itr_5_norm.columns]
itr_5_norm.isna().sum()
# Out:
# application_id    0.0
# report            0.0
# created_date      0.0
# year              0.0
# itr_type          0.0
# dtype: float64

# %%
itr_6_norm = pd.concat([df_itr6.reset_index(drop=True),pd.json_normalize(df_itr6['report'],sep='_')],axis=1)
itr_6_norm.columns = [s.replace('ITR_ITR5_', '') for s in itr_6_norm.columns]
itr_6_norm.isna().sum()
# Out:
# application_id    0.0
# report            0.0
# created_date      0.0
# year              0.0
# itr_type          0.0
# dtype: float64

# %%
def flatten_json(nested_json):
    out = {}
    def flatten(x,name = ''):
        if type(x) is dict:
            for a in x:
                flatten(x[a],name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a,name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x
    flatten(nested_json)
    return out

# %%
# itr_3 = pd.concat([df_itr3.reset_index(drop=True),pd.json_normalize(df_itr3['flatten'],sep='_')],axis=1)
# itr_4 = pd.concat([df_itr4.reset_index(drop=True),pd.json_normalize(df_itr4['flatten'],sep='_')],axis=1)    
# itr_5 = pd.concat([df_itr5.reset_index(drop=True),pd.json_normalize(df_itr5['flatten'],sep='_')],axis=1)
# itr_6 = pd.concat([df_itr6.reset_index(drop=True),pd.json_normalize(df_itr6['flatten'],sep='_')],axis=1)

# %%
# itr_3.head()

# %%
# itr_4.head()

# %%
# itr_3.columns

# %%
# for i in enumerate(itr_3):
#     print(itr_3[i[1]][0])

# %%
df = pd.read_parquet('ITR_sample.parquet')
df['report'] = df['report'].apply(lambda x: json.loads(x.decode('utf-8')))
df['itr_type']=df.apply(lambda x:list((x['report'])['ITR'].keys())[0], axis=1)
df['itr_type'].unique()
for i in df.iloc[36,:]['report']['ITR']['ITR5'].keys():
        a =df.iloc[36,:]['report']
        print(f'-------------------------------------*****{i}*****--------------------------------------')
        print(a['ITR']['ITR5'][i])
        print('''\n-*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*\n''')
# Out:
# -------------------------------------*****CreationInfo*****--------------------------------------
# {'SWVersionNo': '21.5', 'SWCreatedBy': 'SW20000026', 'JSONCreatedBy': 'SW20000026', 'JSONCreationDate': '2022-01-15', 'IntermediaryCity': 'JAIPUR', 'Digest': 'HLXPhXmxYtMANQPCmhY9Iy/zj0QuczpR5oOVU+zPsVY='}
#
# -*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*
#
# -------------------------------------*****Form_ITR5*****--------------------------------------
# {'FormName': 'ITR-5', 'Description': 'For firms, AOPs and BOIs', 'AssessmentYear': '2021', 'SchemaVer': 'Ver1.1', 'FormVer': 'Ver1.0'}
#
# -*-*-*-*-*-*-*-*-**-*-*-*-*-*-*-***-*-*-*-*-*-*--*-*-*-*-*-*
#
# -------------------------------------*****PartA_GEN1*****--------------------------------------
# ...

# %%
# itr_6.head()

# %%
def get_data_as_frame(df,itr_type):
    df['itr_type']=df.apply(lambda x:list((x['report'])['ITR'].keys())[0], axis=1)
    df_itr = df[df['itr_type'] == f'ITR{itr_type}']
    df_itr['flatten'] = df_itr['report'].apply(flatten_json)
    itr_data = pd.concat([df_itr.reset_index(drop=True),pd.json_normalize(df_itr['flatten'],sep='_')],axis=1)
    return itr_data




data_itr4 = get_data_as_frame(df,4)
# Out:
# C:\Users\viral.sherathiya\AppData\Local\Temp\ipykernel_9556\2439006837.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_itr['flatten'] = df_itr['report'].apply(flatten_json)

# %%
data_itr4.head()
# Out:
#    application_id                                             report
# 0         1572080  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...  \
# 1         1572080  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...
# 2         1572147  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...
# 3         1572144  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...
# 4         1572144  {'ITR': {'ITR4': {'CreationInfo': {'SWVersionN...
#
#          created_date  year itr_type
# 0 2023-04-13 16:49:00  2022     ITR4  \
# 1 2023-04-13 16:49:00  2021     ITR4
# 2 2023-04-13 23:56:40  2022     ITR4
# 3 2023-04-12 23:19:09  2022     ITR4
# 4 2023-04-12 23:19:09  2021     ITR4
#
#                                              flatten
# 0  {'ITR_ITR4_CreationInfo_SWVersionNo': 'R9', 'I...  \
# 1  {'ITR_ITR4_CreationInfo_SWVersionNo': '1.0', '...
# 2  {'ITR_ITR4_CreationInfo_SWVersionNo': 'R1', 'I...
# 3  {'ITR_ITR4_CreationInfo_SWVersionNo': '22.0', ...
# ...

# %%
from collections import defaultdict
import jsonpath_ng as jp
import re

auto_id_field = 'json_path'
jp.jsonpath.auto_id_field = auto_id_field
def flatten_nested_json(d: dict)-> dict:
    expr = jp.parse(f'$..*.{auto_id_field}')
    pat = re.compile(r'(?:\.\[\d+]\.|\.)')
    dd = defaultdict(list)
    for m in expr.find(d):
        if not isinstance(m.datum.value, (dict, list)):
            dd[pat.sub('_', m.value)].append(m.datum.value)
    for k, v in dd.items():
        if len(v) == 1:
            dd[k] = v[0]
    return dict(dd)

# %%
# def flatten_json(nested_json, separator='_', prefix=''):
#     """
#     Flatten a nested JSON object.

#     Args:
#         nested_json (dict): The nested JSON object to flatten.
#         separator (str, optional): The separator to use between keys in the flattened dictionary.
#             Defaults to '_'.
#         prefix (str, optional): A prefix to add to each key in the flattened dictionary.
#             Defaults to ''.

#     Returns:
#         dict: The flattened dictionary.
#     """
#     flattened = {}
#     for key, value in nested_json.items():
#         if isinstance(value, dict):
#             # Recursively flatten nested dictionaries
#             flattened.update(flatten_json(value, separator, prefix + key + separator))
#         elif isinstance(value, list):
#             # Flatten each item in a list
#             for i, item in enumerate(value):
#                 flattened.update(flatten_json(item, separator, prefix + key + separator + str(i) + separator))
#         else:
#             # Add the key-value pair to the flattened dictionary
#             flattened[prefix + key] = value
#     return flattened

# %%
df_itr3['flatten123']=df_itr3['report'].apply(flatten_nested_json)

# %%
df_itr3['flatten']=df_itr3['report'].apply(flatten_nested_json)
df_itr_3_norm = pd.concat([df_itr3.reset_index(drop=True),pd.json_normalize(df_itr3['flatten'])],axis=1)
df_itr4['flatten']=df_itr4['report'].apply(flatten_nested_json)
df_itr_4_norm = pd.concat([df_itr4.reset_index(drop=True),pd.json_normalize(df_itr4['flatten'])],axis=1)

df_itr5['flatten']=df_itr5['report'].apply(flatten_nested_json)
df_itr_5_norm = pd.concat([df_itr5.reset_index(drop=True),pd.json_normalize(df_itr5['flatten'])],axis=1)

df_itr6['flatten']=df_itr6['report'].apply(flatten_nested_json)
df_itr_6_norm = pd.concat([df_itr6.reset_index(drop=True),pd.json_normalize(df_itr6['flatten'])],axis=1)

# %%
df_itr4.head()
# Out:
# Empty DataFrame
# Columns: [application_id, report, created_date, year, itr_type, flatten]
# Index: []

# %%
df_itr3.head()
# Out:
#    application_id                                             report
# 0         1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...  \
# 1         1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 2         1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 3         1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 4         1572177  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
#
#          created_date  year itr_type
# 0 2023-04-12 13:07:07  2022     ITR3  \
# 1 2023-04-12 13:07:07  2021     ITR3
# 2 2023-04-14 12:23:11  2022     ITR3
# 3 2023-04-14 12:23:11  2021     ITR3
# 4 2023-04-12 13:07:07  2022     ITR3
#
#                                           flatten123
# 0  {'ITR_ITR3_CreationInfo_SWVersionNo': 'R1', 'I...  \
# 1  {'ITR_ITR3_CreationInfo_SWVersionNo': 'R1', 'I...
# 2  {'ITR_ITR3_CreationInfo_SWVersionNo': '2.22.10...
# 3  {'ITR_ITR3_CreationInfo_SWVersionNo': '2.22.3'...
# ...

# %%
df_itr5.head()
# Out:
# Empty DataFrame
# Columns: [application_id, report, created_date, year, itr_type, flatten]
# Index: []

# %%
df_itr6.head()
# Out:
# Empty DataFrame
# Columns: [application_id, report, created_date, year, itr_type, flatten]
# Index: []

# %%
df_itr_3_norm
# Out:
#     application_id                                             report
# 0          1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...  \
# 1          1572180  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 2          1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 3          1572178  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 4          1572177  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 5          1572177  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 6          1571892  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 7          1571892  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 8          1572167  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 9          1571236  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 10         1572171  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# 11         1572166  {'ITR': {'ITR3': {'CreationInfo': {'SWVersionN...
# ...

# %%
df_itr_4_norm.head()
# Out:
# Empty DataFrame
# Columns: [application_id, report, created_date, year, itr_type, flatten]
# Index: []

# %%
df_itr_5_norm.head()
# Out:
# Empty DataFrame
# Columns: [application_id, report, created_date, year, itr_type, flatten]
# Index: []

# %%
df_itr_6_norm.head()
# Out:
# Empty DataFrame
# Columns: [application_id, report, created_date, year, itr_type, flatten]
# Index: []

# %%
# PartA_GEN1_FilingStatus_CompDirectorPrvYr_CompDirectorPrvYrDtls_0_NameOfCompany
# PartA_GEN1_FilingStatus_CompDirectorPrvYr_CompDirectorPrvYrDtls_0_CompanyType
# PartA_GEN1_FilingStatus_CompDirectorPrvYr_CompDirectorPrvYrDtls_0_PAN
# PartA_GEN1_FilingStatus_CompDirectorPrvYr_CompDirectorPrvYrDtls_0_SharesTypes
# PartA_GEN1_FilingStatus_CompDirectorPrvYr_CompDirectorPrvYrDtls_0_DIN
# PartA_GEN1_FilingStatus_CompDirectorPrvYr_CompDirectorPrvYrDtls_1_NameOfCompany
# PartA_GEN1_FilingStatus_CompDirectorPrvYr_CompDirectorPrvYrDtls_1_CompanyType
# PartA_GEN1_FilingStatus_CompDirectorPrvYr_CompDirectorPrvYrDtls_1_PAN
# PartA_GEN1_FilingStatus_CompDirectorPrvYr_CompDirectorPrvYrDtls_1_SharesTypes
# PartA_GEN1_FilingStatus_CompDirectorPrvYr_CompDirectorPrvYrDtls_1_DIN
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_0_NameOfCompany
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_0_CompanyType
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_0_PAN
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_0_OpngBalNumberOfShares
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_0_OpngBalCostOfAcquisition
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_0_ClsngBalNumberOfShares
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_0_ClsngBalCostOfAcquisition
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_1_NameOfCompany
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_1_CompanyType
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_1_PAN
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_1_OpngBalNumberOfShares
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_1_OpngBalCostOfAcquisition
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_1_ClsngBalNumberOfShares
# PartA_GEN1_FilingStatus_HeldUnlistedEqShrPrYr_HeldUnlistedEqShrPrYrDtls_1_ClsngBalCostOfAcquisition


# ScheduleS_Salaries_0_NameOfEmployer
# ScheduleS_Salaries_0_NatureOfEmployment
# ScheduleS_Salaries_0_TANofEmployer
# ScheduleS_Salaries_0_AddressDetail_AddrDetail
# ScheduleS_Salaries_0_AddressDetail_CityOrTownOrDistrict
# ScheduleS_Salaries_0_AddressDetail_StateCode
# ScheduleS_Salaries_0_AddressDetail_PinCode
# ScheduleS_Salaries_0_Salarys_GrossSalary
# ScheduleS_Salaries_0_Salarys_Salary
# ScheduleS_Salaries_0_Salarys_NatureOfSalary_OthersIncDtls_0_NatureDesc
# ScheduleS_Salaries_0_Salarys_NatureOfSalary_OthersIncDtls_0_OthAmount
# ScheduleS_Salaries_0_Salarys_ValueOfPerquisites
# ScheduleS_Salaries_0_Salarys_ProfitsinLieuOfSalary
# ScheduleS_Salaries_0_Salarys_IncomeNotified89A
# ScheduleS_Salaries_0_Salarys_IncomeNotifiedOther89A





# ScheduleCGFor23_ShortTermCapGainFor23_SaleofLandBuild_SaleofLandBuildDtls_0_FullConsideration
# ScheduleCGFor23_ShortTermCapGainFor23_SaleofLandBuild_SaleofLandBuildDtls_0_PropertyValuation
# ScheduleCGFor23_ShortTermCapGainFor23_SaleofLandBuild_SaleofLandBuildDtls_0_FullConsideration50C
# ScheduleCGFor23_ShortTermCapGainFor23_SaleofLandBuild_SaleofLandBuildDtls_0_AquisitCost
# ScheduleCGFor23_ShortTermCapGainFor23_SaleofLandBuild_SaleofLandBuildDtls_0_ImproveCost
# ScheduleCGFor23_ShortTermCapGainFor23_SaleofLandBuild_SaleofLandBuildDtls_0_ExpOnTrans
# ScheduleCGFor23_ShortTermCapGainFor23_SaleofLandBuild_SaleofLandBuildDtls_0_TotalDedn
# ScheduleCGFor23_ShortTermCapGainFor23_SaleofLandBuild_SaleofLandBuildDtls_0_Balance
# ScheduleCGFor23_ShortTermCapGainFor23_SaleofLandBuild_SaleofLandBuildDtls_0_ExemptionOrDednUs54_ExemptionGrandTotal
# ScheduleCGFor23_ShortTermCapGainFor23_SaleofLandBuild_SaleofLandBuildDtls_0_CapgainonAssets
# ScheduleCGFor23_ShortTermCapGainFor23_EquityMFonSTT_0_MFSectionCode
# ScheduleCGFor23_ShortTermCapGainFor23_EquityMFonSTT_0_EquityMFonSTTDtls_FullConsideration
# ScheduleCGFor23_ShortTermCapGainFor23_EquityMFonSTT_0_EquityMFonSTTDtls_DeductSec48_AquisitCost
# ScheduleCGFor23_ShortTermCapGainFor23_EquityMFonSTT_0_EquityMFonSTTDtls_DeductSec48_ImproveCost
# ScheduleCGFor23_ShortTermCapGainFor23_EquityMFonSTT_0_EquityMFonSTTDtls_DeductSec48_ExpOnTrans
# ScheduleCGFor23_ShortTermCapGainFor23_EquityMFonSTT_0_EquityMFonSTTDtls_DeductSec48_TotalDedn
# ScheduleCGFor23_ShortTermCapGainFor23_EquityMFonSTT_0_EquityMFonSTTDtls_BalanceCG
# ScheduleCGFor23_ShortTermCapGainFor23_EquityMFonSTT_0_EquityMFonSTTDtls_LossSec94of7Or94of8
# ScheduleCGFor23_ShortTermCapGainFor23_EquityMFonSTT_0_EquityMFonSTTDtls_CapgainonAssets



# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_DateofPurchase
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_DateofSale
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_FullConsideration
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_PropertyValuation
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_FullConsideration50C
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_AquisitCost
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_AquisitCostIndex
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_ImproveCost
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_ExpOnTrans
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TotalDedn
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_Balance
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_CostOfImprovements_CostOfImprovementsDtls_0_slno
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_CostOfImprovements_CostOfImprovementsDtls_0_ImproveCost
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_CostOfImprovements_CostOfImprovementsDtls_0_ImproveDate
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_CostOfImprovements_CostOfImprovementsDtls_0_CostOfImpIndex
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_CostOfImprovements_CostOfImprovementsDtls_1_slno
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_CostOfImprovements_CostOfImprovementsDtls_1_ImproveCost
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_CostOfImprovements_CostOfImprovementsDtls_1_ImproveDate
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_CostOfImprovements_CostOfImprovementsDtls_1_CostOfImpIndex
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_ExemptionOrDednUs54_ExemptionGrandTotal
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_CapgainonAssets
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_0_NameOfBuyer
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_0_AaadhaarOfBuyer
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_0_PercentageShare
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_0_Amount
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_0_AddressOfProperty
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_0_StateCode
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_0_CountryCode
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_0_PinCode
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_1_NameOfBuyer
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_1_AaadhaarOfBuyer
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_1_PercentageShare
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_1_Amount
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_1_AddressOfProperty
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_1_StateCode
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_1_CountryCode
# ScheduleCGFor23_LongTermCapGain23_SaleofLandBuild_SaleofLandBuildDtls_0_TrnsfImmblPrprty_TrnsfImmblPrprtyDtls_1_PinCode



# ScheduleIT_TaxPayment_0_BSRCode
# ScheduleIT_TaxPayment_0_DateDep
# ScheduleIT_TaxPayment_0_SrlNoOfChaln
# ScheduleIT_TaxPayment_0_Amt
# ScheduleIT_TaxPayment_1_BSRCode
# ScheduleIT_TaxPayment_1_DateDep
# ScheduleIT_TaxPayment_1_SrlNoOfChaln
# ScheduleIT_TaxPayment_1_Amt
# ScheduleIT_TaxPayment_2_BSRCode
# ScheduleIT_TaxPayment_2_DateDep
# ScheduleIT_TaxPayment_2_SrlNoOfChaln
# ScheduleIT_TaxPayment_2_Amt
# ScheduleIT_TaxPayment_3_BSRCode
# ScheduleIT_TaxPayment_3_DateDep
# ScheduleIT_TaxPayment_3_SrlNoOfChaln
# ScheduleIT_TaxPayment_3_Amt
# ScheduleIT_TaxPayment_4_BSRCode
# ScheduleIT_TaxPayment_4_DateDep
# ScheduleIT_TaxPayment_4_SrlNoOfChaln
# ScheduleIT_TaxPayment_4_Amt
# ScheduleTDS1_TDSonSalary_0_EmployerOrDeductorOrCollectDetl_TAN
# ScheduleTDS1_TDSonSalary_0_EmployerOrDeductorOrCollectDetl_EmployerOrDeductorOrCollecterName
# ScheduleTDS1_TDSonSalary_0_IncChrgSal
# ScheduleTDS1_TDSonSalary_0_TotalTDSSal
# ScheduleTDS3_TDS3onOthThanSalDtls_0_TDSCreditName
# ScheduleTDS3_TDS3onOthThanSalDtls_0_PANOfBuyerTenant
# ScheduleTDS3_TDS3onOthThanSalDtls_0_BroughtFwdTDSAmt
# ScheduleTDS3_TDS3onOthThanSalDtls_0_TaxDeductCreditDtls_TaxDeductedOwnHands
# ScheduleTDS3_TDS3onOthThanSalDtls_0_TaxDeductCreditDtls_TaxClaimedOwnHands
# ScheduleTDS3_TDS3onOthThanSalDtls_0_GrossAmount
# ScheduleTDS3_TDS3onOthThanSalDtls_0_HeadOfIncome
# ScheduleTDS3_TDS3onOthThanSalDtls_0_AmtCarriedFwd
# ScheduleTDS3_TDS3onOthThanSalDtls_1_TDSCreditName
# ScheduleTDS3_TDS3onOthThanSalDtls_1_PANOfBuyerTenant
# ScheduleTDS3_TDS3onOthThanSalDtls_1_BroughtFwdTDSAmt
# ScheduleTDS3_TDS3onOthThanSalDtls_1_TaxDeductCreditDtls_TaxDeductedOwnHands
# ScheduleTDS3_TDS3onOthThanSalDtls_1_TaxDeductCreditDtls_TaxClaimedOwnHands
# ScheduleTDS3_TDS3onOthThanSalDtls_1_GrossAmount
# ScheduleTDS3_TDS3onOthThanSalDtls_1_HeadOfIncome
# ScheduleTDS3_TDS3onOthThanSalDtls_1_AmtCarriedFwd
# ScheduleTDS3_TDS3onOthThanSalDtls_2_TDSCreditName
# ScheduleTDS3_TDS3onOthThanSalDtls_2_PANOfBuyerTenant
# ScheduleTDS3_TDS3onOthThanSalDtls_2_DeductedYr
# ScheduleTDS3_TDS3onOthThanSalDtls_2_BroughtFwdTDSAmt
# ScheduleTDS3_TDS3onOthThanSalDtls_2_TaxDeductCreditDtls_TaxDeductedOwnHands
# ScheduleTDS3_TDS3onOthThanSalDtls_2_TaxDeductCreditDtls_TaxClaimedOwnHands
# ScheduleTDS3_TDS3onOthThanSalDtls_2_GrossAmount
# ScheduleTDS3_TDS3onOthThanSalDtls_2_HeadOfIncome
# ScheduleTDS3_TDS3onOthThanSalDtls_2_AmtCarriedFwd
# ScheduleTDS3_TDS3onOthThanSalDtls_3_TDSCreditName
# ScheduleTDS3_TDS3onOthThanSalDtls_3_PANOfBuyerTenant
# ScheduleTDS3_TDS3onOthThanSalDtls_3_DeductedYr
# ScheduleTDS3_TDS3onOthThanSalDtls_3_BroughtFwdTDSAmt
# ScheduleTDS3_TDS3onOthThanSalDtls_3_TaxDeductCreditDtls_TaxDeductedOwnHands
# ScheduleTDS3_TDS3onOthThanSalDtls_3_TaxDeductCreditDtls_TaxClaimedOwnHands
# ScheduleTDS3_TDS3onOthThanSalDtls_3_GrossAmount
# ScheduleTDS3_TDS3onOthThanSalDtls_3_HeadOfIncome
# ScheduleTDS3_TDS3onOthThanSalDtls_3_AmtCarriedFwd



# ScheduleAL_ImmovableDetails_3_Description
# ScheduleAL_ImmovableDetails_3_AddressAL_ResidenceNo
# ScheduleAL_ImmovableDetails_3_AddressAL_ResidenceName
# ScheduleAL_ImmovableDetails_3_AddressAL_RoadOrStreet
# ScheduleAL_ImmovableDetails_3_AddressAL_LocalityOrArea
# ScheduleAL_ImmovableDetails_3_AddressAL_CityOrTownOrDistrict
# ScheduleAL_ImmovableDetails_3_AddressAL_StateCode
# ScheduleAL_ImmovableDetails_3_AddressAL_CountryCode
# ScheduleAL_ImmovableDetails_3_AddressAL_PinCode
# ScheduleAL_ImmovableDetails_3_Amount





# ScheduleCGFor23_LongTermCapGain23_Proviso112Applicable_0_Proviso112SectionCode
# ScheduleCGFor23_LongTermCapGain23_Proviso112Applicable_0_Proviso112Applicabledtls_FullConsideration
# ScheduleCGFor23_LongTermCapGain23_Proviso112Applicable_0_Proviso112Applicabledtls_DeductSec48_AquisitCost
# ScheduleCGFor23_LongTermCapGain23_Proviso112Applicable_0_Proviso112Applicabledtls_DeductSec48_ImproveCost
# ScheduleCGFor23_LongTermCapGain23_Proviso112Applicable_0_Proviso112Applicabledtls_DeductSec48_ExpOnTrans
# ScheduleCGFor23_LongTermCapGain23_Proviso112Applicable_0_Proviso112Applicabledtls_DeductSec48_TotalDedn
# ScheduleCGFor23_LongTermCapGain23_Proviso112Applicable_0_Proviso112Applicabledtls_BalanceCG
# ScheduleCGFor23_LongTermCapGain23_Proviso112Applicable_0_Proviso112Applicabledtls_DeductionUs54F
# ScheduleCGFor23_LongTermCapGain23_Proviso112Applicable_0_Proviso112Applicabledtls_CapgainonAssets
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_SectionCode
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_FullValueConsdRecvUnqshr
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_FairMrktValueUnqshr
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_FullValueConsdSec50CA
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_FullValueConsdOthUnqshr
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_FullConsideration
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_DeductSec48_AquisitCost
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_DeductSec48_ImproveCost
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_DeductSec48_ExpOnTrans
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_DeductSec48_TotalDedn
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_BalanceCG
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_DeductionUs54F
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_0_CapgainonAssets
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_SectionCode
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_FullValueConsdRecvUnqshr
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_FairMrktValueUnqshr
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_FullValueConsdSec50CA
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_FullValueConsdOthUnqshr
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_FullConsideration
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_DeductSec48_AquisitCost
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_DeductSec48_ImproveCost
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_DeductSec48_ExpOnTrans
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_DeductSec48_TotalDedn
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_BalanceCG
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_DeductionUs54F
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_1_CapgainonAssets
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_SectionCode
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_FullValueConsdRecvUnqshr
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_FairMrktValueUnqshr
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_FullValueConsdSec50CA
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_FullValueConsdOthUnqshr
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_FullConsideration
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_DeductSec48_AquisitCost
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_DeductSec48_ImproveCost
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_DeductSec48_ExpOnTrans
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_DeductSec48_TotalDedn
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_BalanceCG
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_DeductionUs54F
# ScheduleCGFor23_LongTermCapGain23_NRIOnSec112and115_NRIOnSec112and115Dtls_2_CapgainonAssets



# Schedule112A_Schedule112ADtls_0_ShareOnOrBefore
# Schedule112A_Schedule112ADtls_0_ISINCode
# Schedule112A_Schedule112ADtls_0_ShareUnitName
# Schedule112A_Schedule112ADtls_0_NumSharesUnits
# Schedule112A_Schedule112ADtls_0_SalePricePerShareUnit
# Schedule112A_Schedule112ADtls_0_TotSaleValue
# Schedule112A_Schedule112ADtls_0_CostAcqWithoutIndx
# Schedule112A_Schedule112ADtls_0_AcquisitionCost
# Schedule112A_Schedule112ADtls_0_LTCGBeforelower6and11
# Schedule112A_Schedule112ADtls_0_FairMktValuePerShareunit
# Schedule112A_Schedule112ADtls_0_TotFairMktValueCapAst
# Schedule112A_Schedule112ADtls_0_ExpExclCnctTransfer
# Schedule112A_Schedule112ADtls_0_TotalDeductions
# Schedule112A_Schedule112ADtls_0_Balance
# Schedule112A_Schedule112ADtls_1_ShareOnOrBefore
# Schedule112A_Schedule112ADtls_1_ISINCode
# Schedule112A_Schedule112ADtls_1_ShareUnitName
# Schedule112A_Schedule112ADtls_1_NumSharesUnits
# Schedule112A_Schedule112ADtls_1_SalePricePerShareUnit
# Schedule112A_Schedule112ADtls_1_TotSaleValue
# Schedule112A_Schedule112ADtls_1_CostAcqWithoutIndx
# Schedule112A_Schedule112ADtls_1_AcquisitionCost
# Schedule112A_Schedule112ADtls_1_LTCGBeforelower6and11
# Schedule112A_Schedule112ADtls_1_FairMktValuePerShareunit
# Schedule112A_Schedule112ADtls_1_TotFairMktValueCapAst
# Schedule112A_Schedule112ADtls_1_ExpExclCnctTransfer
# Schedule112A_Schedule112ADtls_1_TotalDeductions
# Schedule112A_Schedule112ADtls_1_Balance
# Schedule112A_Schedule112ADtls_2_ShareOnOrBefore
# Schedule112A_Schedule112ADtls_2_ISINCode
# Schedule112A_Schedule112ADtls_2_ShareUnitName
# Schedule112A_Schedule112ADtls_2_NumSharesUnits
# Schedule112A_Schedule112ADtls_2_SalePricePerShareUnit
# Schedule112A_Schedule112ADtls_2_TotSaleValue
# Schedule112A_Schedule112ADtls_2_CostAcqWithoutIndx
# Schedule112A_Schedule112ADtls_2_AcquisitionCost
# Schedule112A_Schedule112ADtls_2_LTCGBeforelower6and11
# Schedule112A_Schedule112ADtls_2_FairMktValuePerShareunit
# Schedule112A_Schedule112ADtls_2_TotFairMktValueCapAst
# Schedule112A_Schedule112ADtls_2_ExpExclCnctTransfer
# Schedule112A_Schedule112ADtls_2_TotalDeductions
# Schedule112A_Schedule112ADtls_2_Balance



# ScheduleIF_PartnerFirmDetails_0_FirmName
# ScheduleIF_PartnerFirmDetails_0_FirmPAN
# ScheduleIF_PartnerFirmDetails_0_IsLiableToAudit
# ScheduleIF_PartnerFirmDetails_0_Sec92EFirmFlag
# ScheduleIF_PartnerFirmDetails_0_ProfitSharePercent
# ScheduleIF_PartnerFirmDetails_0_ProfitShareAmt
# ScheduleIF_PartnerFirmDetails_0_FirmCapBalOn31Mar



# PARTA_QD_TradingConcern_QuantitDet_0_ItemName
# PARTA_QD_TradingConcern_QuantitDet_0_UnitOfMeasure
# PARTA_QD_TradingConcern_QuantitDet_0_OpeningStock
# PARTA_QD_TradingConcern_QuantitDet_0_PurchaseQty
# PARTA_QD_TradingConcern_QuantitDet_0_SaleQty
# PARTA_QD_TradingConcern_QuantitDet_0_ClgStock
# PARTA_QD_TradingConcern_QuantitDet_0_AnyShortExces
# PARTA_QD_TradingConcern_QuantitDet_1_ItemName
# PARTA_QD_TradingConcern_QuantitDet_1_UnitOfMeasure
# PARTA_QD_TradingConcern_QuantitDet_1_OpeningStock
# PARTA_QD_TradingConcern_QuantitDet_1_PurchaseQty
# PARTA_QD_TradingConcern_QuantitDet_1_SaleQty
# PARTA_QD_TradingConcern_QuantitDet_1_ClgStock
# PARTA_QD_TradingConcern_QuantitDet_1_AnyShortExces
# PARTA_QD_TradingConcern_QuantitDet_2_ItemName
# PARTA_QD_TradingConcern_QuantitDet_2_UnitOfMeasure
# PARTA_QD_TradingConcern_QuantitDet_2_OpeningStock
# PARTA_QD_TradingConcern_QuantitDet_2_PurchaseQty
# PARTA_QD_TradingConcern_QuantitDet_2_SaleQty
# PARTA_QD_TradingConcern_QuantitDet_2_ClgStock
# PARTA_QD_TradingConcern_QuantitDet_2_AnyShortExces
